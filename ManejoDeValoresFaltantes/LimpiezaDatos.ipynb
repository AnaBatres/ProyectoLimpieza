# %%
import numpy as np
import pandas as pd
from sklearn.impute import SimpleImputer

df = pd.read_csv('../Product_v6.csv')

# %% [markdown]
# # **1. Manejo de valores faltantes con NumPy**

# %%
# Creamos una columna numerica con valores vacios
df["columnaNumerica"] = np.random.choice([np.nan, 234, 56, 129], size=len(df))

valores_nan = np.isnan(df["columnaNumerica"]) 
print("¿Dónde hay valores NaN?:", valores_nan)

# Creamos un contador para que nos diga la cantidad de valores nan de la columna
print("Valores NaN en total:", df["columnaNumerica"].isna().sum())

mean_value = np.nanmean(df["columnaNumerica"]) 
print(f"Media sin contar los NaN:, {mean_value:.2f}")

median_value = np.nanmedian(df["columnaNumerica"])
std_value = np.nanstd(df["columnaNumerica"]) 
print("Mediana:", median_value, "| Desviación estándar:", round(std_value, 2))

data_filled = np.where(np.isnan(df["columnaNumerica"]), mean_value, df["columnaNumerica"])
print("Array con NaN reemplazados por la media:", data_filled)

data_zero_filled = np.nan_to_num(df["columnaNumerica"], nan=0)
print("Array con NaN reemplazados por 0:", data_zero_filled)

data_clean = df["columnaNumerica"][~np.isnan(df["columnaNumerica"])]
print("Array sin valores NaN:", data_clean)

finite_values = df["columnaNumerica"][np.isfinite(df["columnaNumerica"])] 
print("Valores finitos (sin NaN ni infinitos):", finite_values)






df
# Out:
# ¿Dónde hay valores NaN?: 0     False
# 1     False
# 2     False
# 3     False
# 4     False
#       ...
# 81     True
# 82    False
# 83    False
# 84    False
# 85    False
# Name: columnaNumerica, Length: 86, dtype: bool
# Valores NaN en total: 20
# Media sin contar los NaN:, 135.38
# Mediana: 129.0 | Desviación estándar: 71.81
# Array con NaN reemplazados por la media: [ 56.          56.          56.         234.          56.
#  129.         129.         135.37878788 135.37878788 135.37878788
#  234.          56.          56.         234.          56.
#  129.         129.         234.         234.         129.
#   56.         129.         135.37878788 135.37878788 129.
#  234.         135.37878788 234.         135.37878788 135.37878788
#   56.         234.         129.         135.37878788 234.
#   56.          56.          56.         135.37878788 129.
#  135.37878788 135.37878788  56.         129.          56.
#  135.37878788 135.37878788 234.         234.         135.37878788
#   56.         129.         129.         234.          56.
#  234.         129.         135.37878788 129.         129.
#  129.         234.         129.         234.          56.
#  129.         135.37878788 129.          56.          56.
#   56.         234.         135.37878788  56.          56.
#  234.         129.         135.37878788 129.         234.
#  234.         135.37878788 129.          56.         129.
#  234.        ]
# Array con NaN reemplazados por 0: [ 56.  56.  56. 234.  56. 129. 129.   0.   0.   0. 234.  56.  56. 234.
#   56. 129. 129. 234. 234. 129.  56. 129.   0.   0. 129. 234.   0. 234.
#    0.   0.  56. 234. 129.   0. 234.  56.  56.  56.   0. 129.   0.   0.
#   56. 129.  56.   0.   0. 234. 234.   0.  56. 129. 129. 234.  56. 234.
#  129.   0. 129. 129. 129. 234. 129. 234.  56. 129.   0. 129.  56.  56.
#   56. 234.   0.  56.  56. 234. 129.   0. 129. 234. 234.   0. 129.  56.
#  129. 234.]
# Array sin valores NaN: 0      56.0
# 1      56.0
# 2      56.0
# 3     234.0
# 4      56.0
#       ...
# 81      0.0
# 82    129.0
# 83     56.0
# 84    129.0
# 85    234.0
# Name: columnaNumerica, Length: 86, dtype: float64
# Valores finitos (sin NaN ni infinitos): 0      56.0
# 1      56.0
# 2      56.0
# 3     234.0
# 4      56.0
#       ...
# 81      0.0
# 82    129.0
# 83     56.0
# 84    129.0
# 85    234.0
# Name: columnaNumerica, Length: 86, dtype: float64
#     partNumber productType       category.code     brand.code  \
# 0   PS-SL-A287     PRODUCT     Street Lighting  Public Sector
# 1   PS-SL-A288     PRODUCT     Street Lighting  Public Sector
# 2   PS-SL-H309     PRODUCT     Street Lighting  Public Sector
# 3   PS-SL-H310     PRODUCT     Street Lighting  Public Sector
# 4   PS-SL-F342     PRODUCT     Street Lighting  Public Sector
# ..         ...         ...                 ...            ...
# 81    83600200        ITEM  Primary Foundation            NaN
# 82    83600300        ITEM  Primary Foundation            NaN
# 83     9664145        ITEM   Secondary Chassis            NaN
# 84     9664146        ITEM   Secondary Chassis            NaN
# 85     9664147        ITEM   Secondary Chassis            NaN
#
#         family.code line.code  productSegment.code    status   value  \
# 0          Alliance     Rural                  NaN    ACTIVE  1250.0
# 1          Alliance     Rural                  NaN    ACTIVE  1250.0
# 2              Helm     Rural                  NaN    ACTIVE  1250.0
# 3              Helm     Rural                  NaN    ACTIVE  1250.0
# 4   Flatbush Avenue      City                  NaN    ACTIVE  1250.0
# ..              ...       ...                  ...       ...     ...
# 81              NaN       NaN                  NaN    ACTIVE  1287.0
# 82              NaN       NaN                  NaN  INACTIVE  1456.0
# 83              NaN       NaN                  NaN    ACTIVE   833.0
# 84              NaN       NaN                  NaN    ACTIVE  1032.0
# 85              NaN       NaN                  NaN    ACTIVE   976.0
#
#    valueCurrency defaultQuantityUnits  \
# 0           USD                   EA
# 1           USD                   EA
# 2           USD                   EA
# 3           USD                   EA
# 4           USD                   EA
# ..           ...                  ...
# 81          USD                   EA
# 82          USD                   EA
# 83          USD                   EA
# 84          USD                   EA
# 85          USD                   EA
#
#                                                  name  \
# 0    Alliance 150W HPS 25' Luminaire and Pole, Silver
# 1    Alliance 100W HPS 25' Luminaire and Pole, Silver
# 2         Helm 150W HPS 30' Luminaire and Pole, Black
# 3         Helm 100W HPS 30' Luminaire and Pole, Black
# 4   Flatbush Avenue Twin 250W 30' Teardrop Lumi. a...
# ..                                                ...
# 81                Light Pole Foundation, 24" Diameter
# 82                Light Pole Foundation, 30" Diameter
# 83                        Bracket Al Tapered 6' Reach
# 84                        Bracket Al Tapered 8' Reach
# 85                         Bracket Al Tapered 7' Rise
#
#                                           description  plannerCode  \
# 0   Public Sector Street Lighting - Alliance 150W ...     Lighting
# 1   Public Sector Street Lighting - Alliance 100W ...     Lighting
# 2   Public Sector Street Lighting - Helm 150W HPS ...     Lighting
# 3   Public Sector Street Lighting - Helm 100W HPS ...     Lighting
# 4   Public Sector Street Lighting - Flatbush Avenu...     Lighting
# ..                                                ...          ...
# 81  Primary Foundation - Light Pole Foundation, 24...  Mechanicals
# 82  Primary Foundation - Light Pole Foundation, 30...  Mechanicals
# 83    Secondary Chassis - Bracket Al Tapered 6' Reach  Mechanicals
# 84    Secondary Chassis - Bracket Al Tapered 8' Reach  Mechanicals
# 85     Secondary Chassis - Bracket Al Tapered 7' Rise  Mechanicals
#
#                          sourceLink  columnaNumerica
# 0   http://lighttree.com/PS-SL-A287             56.0
# 1   http://lighttree.com/PS-SL-A288             56.0
# 2   http://lighttree.com/PS-SL-H309             56.0
# 3   http://lighttree.com/PS-SL-H310            234.0
# 4   http://lighttree.com/PS-SL-F342             56.0
# ..                              ...              ...
# 81    http://lighttree.com/83600200              0.0
# 82    http://lighttree.com/83600300            129.0
# 83     http://lighttree.com/9664145             56.0
# 84     http://lighttree.com/9664146            129.0
# 85     http://lighttree.com/9664147            234.0
#
# [86 rows x 16 columns]

# %% [markdown]
# # **2. Manejo de valores faltantes con Pandas**

# %%
# Detectar valores NaN y valores NO null
print(df.isna(), df.notna())

# Eliminar filas y columnas con valores NaN
df_dropped = df.dropna()
df_dropped_cols = df.dropna(axis=1)
print("Dropped", df_dropped, df_dropped_cols)

df["columnaNumericaPandas"] = np.random.choice([np.nan, 234, 56, 129], size=len(df))

# Rellenar NaN con la media y la mediana de cada columna
df["columnaNumericaPandasMedia"] = df["columnaNumericaPandas"].fillna(df["columnaNumericaPandas"].mean().round())
df["columnaNumericaPandasMediana"] = df["columnaNumericaPandas"].fillna(df["columnaNumericaPandas"].median().round())
# Estos solo funciona si todas las columnas en df son numéricas --> df_filled = df.fillna(df.mean()), df_filled_median = df.fillna(df.median())

# Rellenar NaN con el valor más frecuente (moda)
df_filled_mode = df.fillna(df.mode().iloc[0])
print("Valor mas frecuente con NaN", df_filled_mode)


df
# Out:
#     partNumber  productType  category.code  brand.code  family.code  \
# 0        False        False          False       False        False
# 1        False        False          False       False        False
# 2        False        False          False       False        False
# 3        False        False          False       False        False
# 4        False        False          False       False        False
# ..         ...          ...            ...         ...          ...
# 81       False        False          False        True         True
# 82       False        False          False        True         True
# 83       False        False          False        True         True
# 84       False        False          False        True         True
# 85       False        False          False        True         True
#
#     line.code  productSegment.code  status  value  valueCurrency  \
# 0       False                 True   False  False          False
# 1       False                 True   False  False          False
# 2       False                 True   False  False          False
# 3       False                 True   False  False          False
# 4       False                 True   False  False          False
# ..        ...                  ...     ...    ...            ...
# 81       True                 True   False  False          False
# 82       True                 True   False  False          False
# 83       True                 True   False  False          False
# 84       True                 True   False  False          False
# 85       True                 True   False  False          False
#
#     defaultQuantityUnits   name  description  plannerCode  sourceLink  \
# 0                  False  False        False        False       False
# 1                  False  False        False        False       False
# 2                  False  False        False        False       False
# 3                  False  False        False        False       False
# 4                  False  False        False        False       False
# ..                   ...    ...          ...          ...         ...
# 81                 False  False        False        False       False
# 82                 False  False        False        False       False
# 83                 False  False        False        False       False
# 84                 False  False        False        False       False
# 85                 False  False        False        False       False
#
#     columnaNumerica  columnaNumericaPandas  columnaNumericaPandasMedia  \
# 0             False                   True                       False
# 1             False                  False                       False
# 2             False                  False                       False
# 3             False                  False                       False
# 4             False                  False                       False
# ..              ...                    ...                         ...
# 81            False                  False                       False
# 82            False                  False                       False
# 83            False                  False                       False
# 84            False                  False                       False
# 85            False                  False                       False
#
#     columnaNumericaPandasMediana
# 0                          False
# 1                          False
# 2                          False
# 3                          False
# 4                          False
# ..                           ...
# 81                         False
# 82                         False
# 83                         False
# 84                         False
# 85                         False
#
# [86 rows x 19 columns]     partNumber  productType  category.code  brand.code  family.code  \
# 0         True         True           True        True         True
# 1         True         True           True        True         True
# 2         True         True           True        True         True
# 3         True         True           True        True         True
# 4         True         True           True        True         True
# ..         ...          ...            ...         ...          ...
# 81        True         True           True       False        False
# 82        True         True           True       False        False
# 83        True         True           True       False        False
# 84        True         True           True       False        False
# 85        True         True           True       False        False
#
#     line.code  productSegment.code  status  value  valueCurrency  \
# 0        True                False    True   True           True
# 1        True                False    True   True           True
# 2        True                False    True   True           True
# 3        True                False    True   True           True
# 4        True                False    True   True           True
# ..        ...                  ...     ...    ...            ...
# 81      False                False    True   True           True
# 82      False                False    True   True           True
# 83      False                False    True   True           True
# 84      False                False    True   True           True
# 85      False                False    True   True           True
#
#     defaultQuantityUnits  name  description  plannerCode  sourceLink  \
# 0                   True  True         True         True        True
# 1                   True  True         True         True        True
# 2                   True  True         True         True        True
# 3                   True  True         True         True        True
# 4                   True  True         True         True        True
# ..                   ...   ...          ...          ...         ...
# 81                  True  True         True         True        True
# 82                  True  True         True         True        True
# 83                  True  True         True         True        True
# 84                  True  True         True         True        True
# 85                  True  True         True         True        True
#
#     columnaNumerica  columnaNumericaPandas  columnaNumericaPandasMedia  \
# 0              True                  False                        True
# 1              True                   True                        True
# 2              True                   True                        True
# 3              True                   True                        True
# 4              True                   True                        True
# ..              ...                    ...                         ...
# 81             True                   True                        True
# 82             True                   True                        True
# 83             True                   True                        True
# 84             True                   True                        True
# 85             True                   True                        True
#
#     columnaNumericaPandasMediana
# 0                           True
# 1                           True
# 2                           True
# 3                           True
# 4                           True
# ..                           ...
# 81                          True
# 82                          True
# 83                          True
# 84                          True
# 85                          True
#
# [86 rows x 19 columns]
# Dropped Empty DataFrame
# Columns: [partNumber, productType, category.code, brand.code, family.code, line.code, productSegment.code, status, value, valueCurrency, defaultQuantityUnits, name, description, plannerCode, sourceLink, columnaNumerica, columnaNumericaPandas, columnaNumericaPandasMedia, columnaNumericaPandasMediana]
# Index: []     partNumber productType       category.code    status   value  \
# 0   PS-SL-A287     PRODUCT     Street Lighting    ACTIVE  1250.0
# 1   PS-SL-A288     PRODUCT     Street Lighting    ACTIVE  1250.0
# 2   PS-SL-H309     PRODUCT     Street Lighting    ACTIVE  1250.0
# 3   PS-SL-H310     PRODUCT     Street Lighting    ACTIVE  1250.0
# 4   PS-SL-F342     PRODUCT     Street Lighting    ACTIVE  1250.0
# ..         ...         ...                 ...       ...     ...
# 81    83600200        ITEM  Primary Foundation    ACTIVE  1287.0
# 82    83600300        ITEM  Primary Foundation  INACTIVE  1456.0
# 83     9664145        ITEM   Secondary Chassis    ACTIVE   833.0
# 84     9664146        ITEM   Secondary Chassis    ACTIVE  1032.0
# 85     9664147        ITEM   Secondary Chassis    ACTIVE   976.0
#
#    valueCurrency defaultQuantityUnits  \
# 0           USD                   EA
# 1           USD                   EA
# 2           USD                   EA
# 3           USD                   EA
# 4           USD                   EA
# ..           ...                  ...
# 81          USD                   EA
# 82          USD                   EA
# 83          USD                   EA
# 84          USD                   EA
# 85          USD                   EA
#
#                                                  name  \
# 0    Alliance 150W HPS 25' Luminaire and Pole, Silver
# 1    Alliance 100W HPS 25' Luminaire and Pole, Silver
# 2         Helm 150W HPS 30' Luminaire and Pole, Black
# 3         Helm 100W HPS 30' Luminaire and Pole, Black
# 4   Flatbush Avenue Twin 250W 30' Teardrop Lumi. a...
# ..                                                ...
# 81                Light Pole Foundation, 24" Diameter
# 82                Light Pole Foundation, 30" Diameter
# 83                        Bracket Al Tapered 6' Reach
# 84                        Bracket Al Tapered 8' Reach
# 85                         Bracket Al Tapered 7' Rise
#
#                                           description  plannerCode  \
# 0   Public Sector Street Lighting - Alliance 150W ...     Lighting
# 1   Public Sector Street Lighting - Alliance 100W ...     Lighting
# 2   Public Sector Street Lighting - Helm 150W HPS ...     Lighting
# 3   Public Sector Street Lighting - Helm 100W HPS ...     Lighting
# 4   Public Sector Street Lighting - Flatbush Avenu...     Lighting
# ..                                                ...          ...
# 81  Primary Foundation - Light Pole Foundation, 24...  Mechanicals
# 82  Primary Foundation - Light Pole Foundation, 30...  Mechanicals
# 83    Secondary Chassis - Bracket Al Tapered 6' Reach  Mechanicals
# 84    Secondary Chassis - Bracket Al Tapered 8' Reach  Mechanicals
# 85     Secondary Chassis - Bracket Al Tapered 7' Rise  Mechanicals
#
#                          sourceLink  columnaNumerica  \
# 0   http://lighttree.com/PS-SL-A287             56.0
# 1   http://lighttree.com/PS-SL-A288             56.0
# 2   http://lighttree.com/PS-SL-H309             56.0
# 3   http://lighttree.com/PS-SL-H310            234.0
# 4   http://lighttree.com/PS-SL-F342             56.0
# ..                              ...              ...
# 81    http://lighttree.com/83600200              0.0
# 82    http://lighttree.com/83600300            129.0
# 83     http://lighttree.com/9664145             56.0
# 84     http://lighttree.com/9664146            129.0
# 85     http://lighttree.com/9664147            234.0
#
#     columnaNumericaPandasMedia  columnaNumericaPandasMediana
# 0                        146.0                         129.0
# 1                         56.0                          56.0
# 2                        129.0                         129.0
# 3                        129.0                         129.0
# 4                        234.0                         234.0
# ..                         ...                           ...
# 81                        56.0                          56.0
# 82                       234.0                         234.0
# 83                       234.0                         234.0
# 84                       129.0                         129.0
# 85                       129.0                         129.0
#
# [86 rows x 14 columns]
# Valor mas frecuente con NaN     partNumber productType       category.code     brand.code  \
# 0   PS-SL-A287     PRODUCT     Street Lighting  Public Sector
# 1   PS-SL-A288     PRODUCT     Street Lighting  Public Sector
# 2   PS-SL-H309     PRODUCT     Street Lighting  Public Sector
# 3   PS-SL-H310     PRODUCT     Street Lighting  Public Sector
# 4   PS-SL-F342     PRODUCT     Street Lighting  Public Sector
# ..         ...         ...                 ...            ...
# 81    83600200        ITEM  Primary Foundation  Public Sector
# 82    83600300        ITEM  Primary Foundation  Public Sector
# 83     9664145        ITEM   Secondary Chassis  Public Sector
# 84     9664146        ITEM   Secondary Chassis  Public Sector
# 85     9664147        ITEM   Secondary Chassis  Public Sector
#
#         family.code line.code  productSegment.code    status   value  \
# 0          Alliance     Rural                  NaN    ACTIVE  1250.0
# 1          Alliance     Rural                  NaN    ACTIVE  1250.0
# 2              Helm     Rural                  NaN    ACTIVE  1250.0
# 3              Helm     Rural                  NaN    ACTIVE  1250.0
# 4   Flatbush Avenue      City                  NaN    ACTIVE  1250.0
# ..              ...       ...                  ...       ...     ...
# 81              All      City                  NaN    ACTIVE  1287.0
# 82              All      City                  NaN  INACTIVE  1456.0
# 83              All      City                  NaN    ACTIVE   833.0
# 84              All      City                  NaN    ACTIVE  1032.0
# 85              All      City                  NaN    ACTIVE   976.0
#
#    valueCurrency defaultQuantityUnits  \
# 0           USD                   EA
# 1           USD                   EA
# 2           USD                   EA
# 3           USD                   EA
# 4           USD                   EA
# ..           ...                  ...
# 81          USD                   EA
# 82          USD                   EA
# 83          USD                   EA
# 84          USD                   EA
# 85          USD                   EA
#
#                                                  name  \
# 0    Alliance 150W HPS 25' Luminaire and Pole, Silver
# 1    Alliance 100W HPS 25' Luminaire and Pole, Silver
# 2         Helm 150W HPS 30' Luminaire and Pole, Black
# 3         Helm 100W HPS 30' Luminaire and Pole, Black
# 4   Flatbush Avenue Twin 250W 30' Teardrop Lumi. a...
# ..                                                ...
# 81                Light Pole Foundation, 24" Diameter
# 82                Light Pole Foundation, 30" Diameter
# 83                        Bracket Al Tapered 6' Reach
# 84                        Bracket Al Tapered 8' Reach
# 85                         Bracket Al Tapered 7' Rise
#
#                                           description  plannerCode  \
# 0   Public Sector Street Lighting - Alliance 150W ...     Lighting
# 1   Public Sector Street Lighting - Alliance 100W ...     Lighting
# 2   Public Sector Street Lighting - Helm 150W HPS ...     Lighting
# 3   Public Sector Street Lighting - Helm 100W HPS ...     Lighting
# 4   Public Sector Street Lighting - Flatbush Avenu...     Lighting
# ..                                                ...          ...
# 81  Primary Foundation - Light Pole Foundation, 24...  Mechanicals
# 82  Primary Foundation - Light Pole Foundation, 30...  Mechanicals
# 83    Secondary Chassis - Bracket Al Tapered 6' Reach  Mechanicals
# 84    Secondary Chassis - Bracket Al Tapered 8' Reach  Mechanicals
# 85     Secondary Chassis - Bracket Al Tapered 7' Rise  Mechanicals
#
#                          sourceLink  columnaNumerica  columnaNumericaPandas  \
# 0   http://lighttree.com/PS-SL-A287             56.0                   56.0
# 1   http://lighttree.com/PS-SL-A288             56.0                  234.0
# 2   http://lighttree.com/PS-SL-H309             56.0                   56.0
# 3   http://lighttree.com/PS-SL-H310            234.0                  129.0
# 4   http://lighttree.com/PS-SL-F342             56.0                   56.0
# ..                              ...              ...                    ...
# 81    http://lighttree.com/83600200              0.0                  234.0
# 82    http://lighttree.com/83600300            129.0                   56.0
# 83     http://lighttree.com/9664145             56.0                  129.0
# 84     http://lighttree.com/9664146            129.0                  234.0
# 85     http://lighttree.com/9664147            234.0                  129.0
#
#     columnaNumericaPandasMedia  columnaNumericaPandasMediana
# 0                         56.0                          56.0
# 1                        234.0                         234.0
# 2                         56.0                          56.0
# 3                        129.0                         129.0
# 4                        124.0                         129.0
# ..                         ...                           ...
# 81                       234.0                         234.0
# 82                        56.0                          56.0
# 83                       129.0                         129.0
# 84                       234.0                         234.0
# 85                       129.0                         129.0
#
# [86 rows x 19 columns]
#     partNumber productType       category.code     brand.code  \
# 0   PS-SL-A287     PRODUCT     Street Lighting  Public Sector
# 1   PS-SL-A288     PRODUCT     Street Lighting  Public Sector
# 2   PS-SL-H309     PRODUCT     Street Lighting  Public Sector
# 3   PS-SL-H310     PRODUCT     Street Lighting  Public Sector
# 4   PS-SL-F342     PRODUCT     Street Lighting  Public Sector
# ..         ...         ...                 ...            ...
# 81    83600200        ITEM  Primary Foundation            NaN
# 82    83600300        ITEM  Primary Foundation            NaN
# 83     9664145        ITEM   Secondary Chassis            NaN
# 84     9664146        ITEM   Secondary Chassis            NaN
# 85     9664147        ITEM   Secondary Chassis            NaN
#
#         family.code line.code  productSegment.code    status   value  \
# 0          Alliance     Rural                  NaN    ACTIVE  1250.0
# 1          Alliance     Rural                  NaN    ACTIVE  1250.0
# 2              Helm     Rural                  NaN    ACTIVE  1250.0
# 3              Helm     Rural                  NaN    ACTIVE  1250.0
# 4   Flatbush Avenue      City                  NaN    ACTIVE  1250.0
# ..              ...       ...                  ...       ...     ...
# 81              NaN       NaN                  NaN    ACTIVE  1287.0
# 82              NaN       NaN                  NaN  INACTIVE  1456.0
# 83              NaN       NaN                  NaN    ACTIVE   833.0
# 84              NaN       NaN                  NaN    ACTIVE  1032.0
# 85              NaN       NaN                  NaN    ACTIVE   976.0
#
#    valueCurrency defaultQuantityUnits  \
# 0           USD                   EA
# 1           USD                   EA
# 2           USD                   EA
# 3           USD                   EA
# 4           USD                   EA
# ..           ...                  ...
# 81          USD                   EA
# 82          USD                   EA
# 83          USD                   EA
# 84          USD                   EA
# 85          USD                   EA
#
#                                                  name  \
# 0    Alliance 150W HPS 25' Luminaire and Pole, Silver
# 1    Alliance 100W HPS 25' Luminaire and Pole, Silver
# 2         Helm 150W HPS 30' Luminaire and Pole, Black
# 3         Helm 100W HPS 30' Luminaire and Pole, Black
# 4   Flatbush Avenue Twin 250W 30' Teardrop Lumi. a...
# ..                                                ...
# 81                Light Pole Foundation, 24" Diameter
# 82                Light Pole Foundation, 30" Diameter
# 83                        Bracket Al Tapered 6' Reach
# 84                        Bracket Al Tapered 8' Reach
# 85                         Bracket Al Tapered 7' Rise
#
#                                           description  plannerCode  \
# 0   Public Sector Street Lighting - Alliance 150W ...     Lighting
# 1   Public Sector Street Lighting - Alliance 100W ...     Lighting
# 2   Public Sector Street Lighting - Helm 150W HPS ...     Lighting
# 3   Public Sector Street Lighting - Helm 100W HPS ...     Lighting
# 4   Public Sector Street Lighting - Flatbush Avenu...     Lighting
# ..                                                ...          ...
# 81  Primary Foundation - Light Pole Foundation, 24...  Mechanicals
# 82  Primary Foundation - Light Pole Foundation, 30...  Mechanicals
# 83    Secondary Chassis - Bracket Al Tapered 6' Reach  Mechanicals
# 84    Secondary Chassis - Bracket Al Tapered 8' Reach  Mechanicals
# 85     Secondary Chassis - Bracket Al Tapered 7' Rise  Mechanicals
#
#                          sourceLink  columnaNumerica  columnaNumericaPandas  \
# 0   http://lighttree.com/PS-SL-A287             56.0                   56.0
# 1   http://lighttree.com/PS-SL-A288             56.0                  234.0
# 2   http://lighttree.com/PS-SL-H309             56.0                   56.0
# 3   http://lighttree.com/PS-SL-H310            234.0                  129.0
# 4   http://lighttree.com/PS-SL-F342             56.0                    NaN
# ..                              ...              ...                    ...
# 81    http://lighttree.com/83600200              0.0                  234.0
# 82    http://lighttree.com/83600300            129.0                   56.0
# 83     http://lighttree.com/9664145             56.0                  129.0
# 84     http://lighttree.com/9664146            129.0                  234.0
# 85     http://lighttree.com/9664147            234.0                  129.0
#
#     columnaNumericaPandasMedia  columnaNumericaPandasMediana
# 0                         56.0                          56.0
# 1                        234.0                         234.0
# 2                         56.0                          56.0
# 3                        129.0                         129.0
# 4                        124.0                         129.0
# ..                         ...                           ...
# 81                       234.0                         234.0
# 82                        56.0                          56.0
# 83                       129.0                         129.0
# 84                       234.0                         234.0
# 85                       129.0                         129.0
#
# [86 rows x 19 columns]

# %% [markdown]
# # **3. Manejo de valores faltantes con Scikit-learn**

# %%
# Detecta valores NaN
df.isna()

# Eliminar filas con valores NaN
df.dropna()

# Rellena NaN con la media de cada columna imputer = SimpleImputer(strategy="mean")  # Crea un imputador usando la media
# df_imputed = pd.DataFrame(imputer.fit_transform(df), columns=df.columns)  # Aplica la estrategia y crea nuevo DataFrame
# Solo se puede aplicar SimpleImputer a las columnas numéricas

imputer = SimpleImputer(strategy="mean")
df[["value"]] = imputer.fit_transform(df[["value"]])

# RELLENAR NaN con el valor más frecuente de la columna
imputer_freq = SimpleImputer(strategy="most_frequent")  # Usa la moda (valor más frecuente)
df[["value"]] = imputer_freq.fit_transform(df[["value"]])


# RELLENAR NaN con un valor constante (ejemplo: 0)
imputer_const = SimpleImputer(strategy="constant", fill_value=0)  # Rellena con 0 en la misma columna
df[["value"]] = imputer_const.fit_transform(df[["value"]])




df
# Out:
#     partNumber productType       category.code     brand.code  \
# 0   PS-SL-A287     PRODUCT     Street Lighting  Public Sector
# 1   PS-SL-A288     PRODUCT     Street Lighting  Public Sector
# 2   PS-SL-H309     PRODUCT     Street Lighting  Public Sector
# 3   PS-SL-H310     PRODUCT     Street Lighting  Public Sector
# 4   PS-SL-F342     PRODUCT     Street Lighting  Public Sector
# ..         ...         ...                 ...            ...
# 81    83600200        ITEM  Primary Foundation            NaN
# 82    83600300        ITEM  Primary Foundation            NaN
# 83     9664145        ITEM   Secondary Chassis            NaN
# 84     9664146        ITEM   Secondary Chassis            NaN
# 85     9664147        ITEM   Secondary Chassis            NaN
#
#         family.code line.code  productSegment.code    status   value  \
# 0          Alliance     Rural                  NaN    ACTIVE  1250.0
# 1          Alliance     Rural                  NaN    ACTIVE  1250.0
# 2              Helm     Rural                  NaN    ACTIVE  1250.0
# 3              Helm     Rural                  NaN    ACTIVE  1250.0
# 4   Flatbush Avenue      City                  NaN    ACTIVE  1250.0
# ..              ...       ...                  ...       ...     ...
# 81              NaN       NaN                  NaN    ACTIVE  1287.0
# 82              NaN       NaN                  NaN  INACTIVE  1456.0
# 83              NaN       NaN                  NaN    ACTIVE   833.0
# 84              NaN       NaN                  NaN    ACTIVE  1032.0
# 85              NaN       NaN                  NaN    ACTIVE   976.0
#
#    valueCurrency defaultQuantityUnits  \
# 0           USD                   EA
# 1           USD                   EA
# 2           USD                   EA
# 3           USD                   EA
# 4           USD                   EA
# ..           ...                  ...
# 81          USD                   EA
# 82          USD                   EA
# 83          USD                   EA
# 84          USD                   EA
# 85          USD                   EA
#
#                                                  name  \
# 0    Alliance 150W HPS 25' Luminaire and Pole, Silver
# 1    Alliance 100W HPS 25' Luminaire and Pole, Silver
# 2         Helm 150W HPS 30' Luminaire and Pole, Black
# 3         Helm 100W HPS 30' Luminaire and Pole, Black
# 4   Flatbush Avenue Twin 250W 30' Teardrop Lumi. a...
# ..                                                ...
# 81                Light Pole Foundation, 24" Diameter
# 82                Light Pole Foundation, 30" Diameter
# 83                        Bracket Al Tapered 6' Reach
# 84                        Bracket Al Tapered 8' Reach
# 85                         Bracket Al Tapered 7' Rise
#
#                                           description  plannerCode  \
# 0   Public Sector Street Lighting - Alliance 150W ...     Lighting
# 1   Public Sector Street Lighting - Alliance 100W ...     Lighting
# 2   Public Sector Street Lighting - Helm 150W HPS ...     Lighting
# 3   Public Sector Street Lighting - Helm 100W HPS ...     Lighting
# 4   Public Sector Street Lighting - Flatbush Avenu...     Lighting
# ..                                                ...          ...
# 81  Primary Foundation - Light Pole Foundation, 24...  Mechanicals
# 82  Primary Foundation - Light Pole Foundation, 30...  Mechanicals
# 83    Secondary Chassis - Bracket Al Tapered 6' Reach  Mechanicals
# 84    Secondary Chassis - Bracket Al Tapered 8' Reach  Mechanicals
# 85     Secondary Chassis - Bracket Al Tapered 7' Rise  Mechanicals
#
#                          sourceLink
# 0   http://lighttree.com/PS-SL-A287
# 1   http://lighttree.com/PS-SL-A288
# 2   http://lighttree.com/PS-SL-H309
# 3   http://lighttree.com/PS-SL-H310
# 4   http://lighttree.com/PS-SL-F342
# ..                              ...
# 81    http://lighttree.com/83600200
# 82    http://lighttree.com/83600300
# 83     http://lighttree.com/9664145
# 84     http://lighttree.com/9664146
# 85     http://lighttree.com/9664147
#
# [86 rows x 15 columns]
